# %% [markdown]
# ### Homework Rakamin Trial Class - Mini Case

# %% [markdown]
# # Mengukur Performa Penjualan Ritel Online

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

# %%
df_dataset = pd.read_csv('online_retail_II.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_dataset
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# ## Section 1

# %% [markdown]
# ### Create New Feature: Year

# %%
pd.DatetimeIndex(df_dataset['InvoiceDate']).year
# Out:
# Int64Index([2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009,
#             ...
#             2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011],
#            dtype='int64', name='InvoiceDate', length=1067371)

# %%
Year = pd.DataFrame(pd.DatetimeIndex(df_dataset['InvoiceDate']).year)

# %%
from operator import length_hint
length_hint
# Out:
# <function _operator.length_hint(obj, default=0, /)>

# %%
import numpy as np

# %%
from ast import Assign

# %%
df_dataset1 = Assign(Year = pd.DataFrame(pd.DatetimeIndex(df_dataset['InvoiceDate']).year))

# %%
df_dataset1

# %%
df_dataset['Year'] = Year.values

# %%
df_dataset2 = df_dataset.assign(Year=Year.values)

# %%
df_dataset2
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %% [markdown]
# ### Filtering Data

# %%
df_dataset2[df_dataset2['Quantity'] >= 1]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %%
sales = df_dataset2[df_dataset2['Quantity'] >= 1]

# %%
sales
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %% [markdown]
# ### Create New Feature: Revenue

# %%
x = (df_dataset2['Quantity'])
y = (df_dataset2['Price'])

# %%
Revenue = (x*y)

# %%
Revenue
# Out:
# 0           83.40
# 1           81.00
# 2           81.00
# 3          100.80
# 4           30.00
#             ...
# 1067366     12.60
# 1067367     16.60
# 1067368     16.60
# 1067369     14.85
# 1067370     18.00
# Length: 1067371, dtype: float64

# %%
df_dataset2['Revenue'] = Revenue.values

# %%
df_dataset3 = df_dataset2.assign(Revenue=Revenue.values)

# %%
df_dataset3
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year  \
# ...

# %% [markdown]
# ### Average of Revenue per Year

# %%
from numpy.core.fromnumeric import mean
Ave_Revenue = mean(df_dataset3['Revenue']/12)

# %%
Ave_Revenue
# Out:
# 1.5058221374448684

# %% [markdown]
# Year = **2009**

# %%
df_dataset3[df_dataset3['Year'] == 2009]
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 0      489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1      489434    79323P                   PINK CHERRY LIGHTS        12
# 2      489434    79323W                  WHITE CHERRY LIGHTS        12
# 3      489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4      489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...       ...       ...                                  ...       ...
# 45223  493408    90058B  CRYSTAL STUD EARRINGS ASSORTED COL          1
# 45224  493408     21933      PINK VINTAGE PAISLEY PICNIC BAG         1
# 45225  493408     21937              STRAWBERRY   PICNIC BAG         1
# 45226  493408     21936            RED/WHITE SPOT PICNIC BAG         1
# 45227  493409     20747                   PICCADILLY TEA SET        48
#
#                InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
df_dataset3[df_dataset3['Year'] == 2009].shape
# Out:
# (45228, 10)

# %%
Revenue2009 = df_dataset3[df_dataset3['Year'] == 2009]

# %%
Revenue2009
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 0      489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1      489434    79323P                   PINK CHERRY LIGHTS        12
# 2      489434    79323W                  WHITE CHERRY LIGHTS        12
# 3      489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4      489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...       ...       ...                                  ...       ...
# 45223  493408    90058B  CRYSTAL STUD EARRINGS ASSORTED COL          1
# 45224  493408     21933      PINK VINTAGE PAISLEY PICNIC BAG         1
# 45225  493408     21937              STRAWBERRY   PICNIC BAG         1
# 45226  493408     21936            RED/WHITE SPOT PICNIC BAG         1
# 45227  493409     20747                   PICCADILLY TEA SET        48
#
#                InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
from numpy.core.fromnumeric import mean
AveRevenue_2009 = mean(Revenue2009['Revenue'])

# %%
AveRevenue_2009
# Out:
# 17.684777350313965

# %% [markdown]
# Year = **2010**

# %%
df_dataset3[df_dataset3['Year'] == 2010]
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 45228    493410   TEST001          This is a test product.         5
# 45229   C493411     21539          RETRO SPOTS BUTTER DISH        -1
# 45230    493412   TEST001          This is a test product.         5
# 45231    493413     21724  PANDA AND BUNNIES STICKER SHEET         1
# 45232    493413     84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...       ...                              ...       ...
# 567937   539991     21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 567938   539991     72741            GRAND CHOCOLATECANDLE         4
# 567939   539992     21470    FLOWER VINE RAFFIA FOOD COVER         1
# 567940   539992     22258          FELT FARM ANIMAL RABBIT         1
# 567941   539992     21155            RED RETROSPOT PEG BAG         1
#
#                 InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
Revenue2010 = df_dataset3[df_dataset3['Year'] == 2010]

# %%
Revenue2010
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 45228    493410   TEST001          This is a test product.         5
# 45229   C493411     21539          RETRO SPOTS BUTTER DISH        -1
# 45230    493412   TEST001          This is a test product.         5
# 45231    493413     21724  PANDA AND BUNNIES STICKER SHEET         1
# 45232    493413     84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...       ...                              ...       ...
# 567937   539991     21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 567938   539991     72741            GRAND CHOCOLATECANDLE         4
# 567939   539992     21470    FLOWER VINE RAFFIA FOOD COVER         1
# 567940   539992     22258          FELT FARM ANIMAL RABBIT         1
# 567941   539992     21155            RED RETROSPOT PEG BAG         1
#
#                 InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
from numpy.core.fromnumeric import mean
AveRevenue_2010 = mean(Revenue2010['Revenue'])

# %%
AveRevenue_2010
# Out:
# 18.152554827305185

# %% [markdown]
# Year = **2011**

# %%
df_dataset3[df_dataset3['Year'] == 2011]
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 567942   539993     22386          JUMBO BAG PINK POLKADOT        10
# 567943   539993     21499               BLUE POLKADOT WRAP        25
# 567944   539993     21498              RED RETROSPOT WRAP         25
# 567945   539993     22379         RECYCLING BAG RETROSPOT          5
# 567946   539993     20718        RED RETROSPOT SHOPPER BAG        10
# ...         ...       ...                              ...       ...
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year  \
# ...

# %%
Revenue2011 = df_dataset3[df_dataset3['Year'] == 2011]

# %%
Revenue2011
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 567942   539993     22386          JUMBO BAG PINK POLKADOT        10
# 567943   539993     21499               BLUE POLKADOT WRAP        25
# 567944   539993     21498              RED RETROSPOT WRAP         25
# 567945   539993     22379         RECYCLING BAG RETROSPOT          5
# 567946   539993     20718        RED RETROSPOT SHOPPER BAG        10
# ...         ...       ...                              ...       ...
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year  \
# ...

# %%
from numpy.core.fromnumeric import mean
AveRevenue_2011 = mean(Revenue2011['Revenue'])

# %%
AveRevenue_2011
# Out:
# 18.018194606240325

# %% [markdown]
# Visualisasi Rata-Rata Revenue per Tahun

# %%
from prettytable import PrettyTable

# %%
table = PrettyTable(["MeanRevenue","Year"])

# %%
table.add_row(["17.684777350313965","2009"])

# %%
table.add_row(["18.152554827305185","2010"])

# %%
table.add_row(["18.018194606240325","2011"])

# %%
print(table)
# Out:
# +--------------------+------+
# |    MeanRevenue     | Year |
# +--------------------+------+
# | 17.684777350313965 | 2009 |
# | 18.152554827305185 | 2010 |
# | 18.018194606240325 | 2011 |
# +--------------------+------+

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
y = [17.684777350313965, 18.152554827305185, 18.018194606240325]

# %%
x = [2009, 2010, 2011]

# %%
ax = sns.stripplot(x, y);
ax.set(xlabel = 'Year', ylabel = 'MeanRevenue')
plt.title('Grafik Rata-Rata Revenue per Tahun')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Grafik Rata-Rata Revenue per Tahun')

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Penjualan ritel online dalam sebuah perusahaan pada kurun waktu 3 tahun terakhir mulai dari 2009 hingga 2011 mengalami naik-turun. Hal ini dapat ditunjukkan melalui Grafik Rata-Rata Revenue per Tahun seperti di atas, bahwa rata-rata revenue pada tahun 2009 dapat dikatakan cukup rendah karena hanya menyentuh nilai sekitar 17.684777350313965. Penjualan ritel online kemudian mengalami peningkatan yang cukup signifikan pada tahun 2010 karena diperoleh nilai rata-rata revenue per tahun mencapai 18.152554827305185. Peningkatan ini dapat dibilang cukup tinggi jika dibandingkan dengan tahun 2009 lalu. Namun pada tahun 2011, penjualan ritel online kembali mengalami penurunan karena nilai rata-rata revenue per tahun hanya mencapai 18.018194606240325. Perolehan rata-rata revenue pada tahun 2011 tersebut lebih rendah jika dibandingkan dengan tahun 2010, akan tetapi lebih tinggi jika dibandingkan dengan tahun 2009. Dengan demikian, performa penjualan ritel online pada 3 tahun terakhir (2009-2011) dapat dikatakan cukup baik, meskipun grafik pengukuran performa masih mengalami kenaikan dan penurunan.

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# #### Customers who finished their purchases

# %%
sales
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %%
import re

# %%
sales[sales['Customer ID'] >= 1]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %%
finished = sales[sales['Customer ID'] >= 1]

# %%
finished
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %% [markdown]
# #### Customers who canceled their purchases

# %%
df_dataset3[df_dataset3['Invoice'].str.contains('C')]
# Out:
#          Invoice StockCode                       Description  Quantity  \
# 178      C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179      C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180      C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181      C489449     21896                POTTING SHED TWINE        -6
# 182      C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...          ...       ...                               ...       ...
# 1065910  C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 1067002  C581499         M                            Manual        -1
# 1067176  C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 1067177  C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 1067178  C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                  InvoiceDate   Price  Customer ID         Country  Year  \
# ...

# %%
cancel = df_dataset3[df_dataset3['Invoice'].str.contains('C')]

# %%
cancel
# Out:
#          Invoice StockCode                       Description  Quantity  \
# 178      C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179      C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180      C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181      C489449     21896                POTTING SHED TWINE        -6
# 182      C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...          ...       ...                               ...       ...
# 1065910  C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 1067002  C581499         M                            Manual        -1
# 1067176  C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 1067177  C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 1067178  C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                  InvoiceDate   Price  Customer ID         Country  Year  \
# ...

# %% [markdown]
# ### Number of Finished and Canceled Transactions Each Year

# %%
Total_Transaksi_finished = sales[sales['Customer ID'] >= 1].shape

# %%
Total_Transaksi_finished
# Out:
# (805620, 9)

# %%
Total_Transaksi_cancel = df_dataset3[df_dataset3['Invoice'].str.contains('C')].shape

# %%
Total_Transaksi_cancel
# Out:
# (19494, 10)

# %% [markdown]
# Total Transaksi Finished (Year = **2009**)

# %%
Transaksi_finished_2009 = finished[finished['Year'] == 2009]

# %%
Transaksi_finished_2009
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 0      489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1      489434    79323P                   PINK CHERRY LIGHTS        12
# 2      489434    79323W                  WHITE CHERRY LIGHTS        12
# 3      489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4      489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...       ...       ...                                  ...       ...
# 45219  493407     21993           FLORAL FOLK STATIONERY SET         1
# 45220  493407     21992       VINTAGE PAISLEY STATIONERY SET         1
# 45221  493407     21991      BOHEMIAN COLLAGE STATIONERY SET         1
# 45222  493407     21034         REX CASH+CARRY JUMBO SHOPPER        10
# 45227  493409     20747                   PICCADILLY TEA SET        48
#
#                InvoiceDate  Price  Customer ID         Country  Year
# ...

# %%
TotalTransaksi_finished_2009 = Transaksi_finished_2009.shape

# %%
TotalTransaksi_finished_2009
# Out:
# (30761, 9)

# %% [markdown]
# Total Transaksi Finished (Year = **2010**)

# %%
Transaksi_finished_2010 = finished[finished['Year'] == 2010]

# %%
Transaksi_finished_2010
# Out:
#        Invoice StockCode                        Description  Quantity  \
# 45228   493410   TEST001            This is a test product.         5
# 45230   493412   TEST001            This is a test product.         5
# 45234   493414     21844                     RETRO SPOT MUG        36
# 45235   493414     21533          RETRO SPOT LARGE MILK JUG        12
# 45236   493414     37508    NEW ENGLAND CERAMIC CAKE SERVER         2
# ...        ...       ...                                ...       ...
# 567909  539988     84380  SET OF 3 BUTTERFLY COOKIE CUTTERS         1
# 567910  539988    84849D              HOT BATHS SOAP HOLDER         1
# 567911  539988    84849B             FAIRY SOAP SOAP HOLDER         1
# 567912  539988     22854        CREAM SWEETHEART EGG HOLDER         2
# 567913  539988    47559B                TEA TIME OVEN GLOVE         2
#
#                 InvoiceDate  Price  Customer ID         Country  Year
# ...

# %%
TotalTransaksi_finished_2010 = Transaksi_finished_2010.shape

# %%
TotalTransaksi_finished_2010
# Out:
# (403094, 9)

# %% [markdown]
# Total Transaksi Finished (Year = **2011**)

# %%
Transaksi_finished_2011 = finished[finished['Year'] == 2011]

# %%
Transaksi_finished_2011
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 567942   539993     22386          JUMBO BAG PINK POLKADOT        10
# 567943   539993     21499               BLUE POLKADOT WRAP        25
# 567944   539993     21498              RED RETROSPOT WRAP         25
# 567945   539993     22379         RECYCLING BAG RETROSPOT          5
# 567946   539993     20718        RED RETROSPOT SHOPPER BAG        10
# ...         ...       ...                              ...       ...
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %%
TotalTransaksi_finished_2011 = Transaksi_finished_2011.shape

# %%
TotalTransaksi_finished_2011
# Out:
# (371765, 9)

# %% [markdown]
# Total Transaksi Cancel (Year = **2009**)

# %%
Transaksi_cancel_2009 = cancel[cancel['Year'] == 2009]

# %%
Transaksi_cancel_2009
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 178    C489449     22087             PAPER BUNTING WHITE LACE       -12
# 179    C489449    85206A         CREAM FELT EASTER EGG BASKET        -6
# 180    C489449     21895        POTTING SHED SOW 'N' GROW SET        -4
# 181    C489449     21896                   POTTING SHED TWINE        -6
# 182    C489449     22083           PAPER CHAIN KIT RETRO SPOT       -12
# ...        ...       ...                                  ...       ...
# 44706  C493329     22243  HOOK, 5 HANGER ,MAGIC TOADSTOOL RED       -14
# 44707  C493329     22333  RETRO SPORT PARTY BAG + STICKER SET        -1
# 44708  C493332     20952          PORCELAIN CHERUB BELL SMALL       -12
# 44717  C493362    85099C       JUMBO  BAG BAROQUE BLACK WHITE        -2
# 44782  C493373         D                             Discount        -1
#
#                InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
TotalTransaksi_cancel_2009 = Transaksi_cancel_2009.shape

# %%
TotalTransaksi_cancel_2009
# Out:
# (1015, 10)

# %% [markdown]
# Total Transaksi Cancel (Year = **2010**)

# %%
Transaksi_cancel_2010 = cancel[cancel['Year'] == 2010]

# %%
Transaksi_cancel_2010
# Out:
#         Invoice StockCode                         Description  Quantity  \
# 45229   C493411     21539             RETRO SPOTS BUTTER DISH        -1
# 45240   C493415     21527      RETRO SPOT TRADITIONAL TEAPOT         -3
# 45241   C493426     22109        FULL ENGLISH BREAKFAST PLATE        -1
# 45284   C493430     21556        CERAMIC STRAWBERRY MONEY BOX        -1
# 45285   C493430     21232      STRAWBERRY CERAMIC TRINKET BOX        -2
# ...         ...       ...                                 ...       ...
# 567083  C539950    85099C      JUMBO  BAG BAROQUE BLACK WHITE        -1
# 567084  C539950    85099B             JUMBO BAG RED RETROSPOT       -10
# 567085  C539950     22720   SET OF 3 CAKE TINS PANTRY DESIGN         -2
# 567157  C539956    35004C     SET OF 3 COLOURED  FLYING DUCKS       -15
# 567792  C539983     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -6
#
#                 InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
TotalTransaksi_cancel_2010 = Transaksi_cancel_2010.shape

# %%
TotalTransaksi_cancel_2010
# Out:
# (9919, 10)

# %% [markdown]
# Total Transaksi Cancel (Year = **2011**)

# %%
Transaksi_cancel_2011 = cancel[cancel['Year'] == 2011]

# %%
Transaksi_cancel_2011
# Out:
#          Invoice StockCode                          Description  Quantity  \
# 568018   C540006     21306           SET/4 DAISY MIRROR MAGNETS        -1
# 568019   C540006     84352  SILVER CHRISTMAS TREE BAUBLE STAND         -1
# 568020   C540006     22423             REGENCY CAKESTAND 3 TIER        -1
# 568021   C540007     21055                   TOOL BOX SOFT TOY         -6
# 568022   C540007     22274                 FELTCRAFT DOLL EMILY        -6
# ...          ...       ...                                  ...       ...
# 1065910  C581490     23144      ZINC T-LIGHT HOLDER STARS SMALL       -11
# 1067002  C581499         M                               Manual        -1
# 1067176  C581568     21258           VICTORIAN SEWING BOX LARGE        -5
# 1067177  C581569     84978     HANGING HEART JAR T-LIGHT HOLDER        -1
# 1067178  C581569     20979        36 PENCILS TUBE RED RETROSPOT        -5
#
#                  InvoiceDate   Price  Customer ID         Country  Year  \
# ...

# %%
TotalTransaksi_cancel_2011 = Transaksi_cancel_2011.shape

# %%
TotalTransaksi_cancel_2011
# Out:
# (8560, 10)

# %% [markdown]
# Visualisasi Jumlah Transaksi Berhasil dan Transaksi yang dibatalkan Setiap Tahun (2009-2011)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['Finished 2009', 'Finished 2010', 'Finished 2011', 'Cancel 2009', 'Cancel 2010', 'Cancel 2011']
y = [30761, 403094, 371765, 1015, 9919, 8560]

# %%
ax2 = sns.stripplot(x, y);
ax2.set(xlabel = 'Transaksi Finished & Cancel', ylabel = 'Jumlah Transaksi/Tahun')
plt.title('Grafik Jumlah Transaksi Finished & Cancel per Tahun')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Grafik Jumlah Transaksi Finished & Cancel per Tahun')

# %%
x = [2009, 2010, 2011]
y = [30761, 403094, 371765]

# %%
ax3 = sns.stripplot(x, y);
ax3.set(xlabel = 'Tahun', ylabel = 'Jumlah Transaksi Finished/Tahun')
plt.title('Grafik Jumlah Transaksi Finished per Tahun')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Grafik Jumlah Transaksi Finished per Tahun')

# %%
x = [2009, 2010, 2011]
y = [1015, 9919, 8560]

# %%
ax4 = sns.stripplot(x, y);
ax4.set(xlabel = 'Tahun', ylabel = 'Jumlah Transaksi Cancel/Tahun')
plt.title('Grafik Jumlah Transaksi Cancel per Tahun')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Grafik Jumlah Transaksi Cancel per Tahun')

# %% [markdown]
# ### Cancellation Rate

# %%
TotalCustomerCancel = 19494
TotalCustomerAll = 1067371
CustomerCancel_2009 = 1015
CustomerCancel_2010 = 9919
CustomerCancel_2011 = 8560

# %%
Cancellation_rate = sum([TotalCustomerCancel/TotalCustomerAll]*100)

# %%
Cancellation_rate
# Out:
# 1.8263565339511776

# %%
Cancellation_rate_2009 = sum([CustomerCancel_2009/TotalCustomerAll]*100)

# %%
Cancellation_rate_2009
# Out:
# 0.09509345860061758

# %%
Cancellation_rate_2010 = sum([CustomerCancel_2010/TotalCustomerAll]*100)

# %%
Cancellation_rate_2010
# Out:
# 0.9292926264625879

# %%
Cancellation_rate_2011 = sum([CustomerCancel_2011/TotalCustomerAll]*100)

# %%
Cancellation_rate_2011
# Out:
# 0.8019704488879678

# %% [markdown]
# Visualisasi Cancellation Rate per Tahun

# %%
x = [2009, 2010, 2011]
y = [0.09509345860061758, 0.9292926264625879, 0.8019704488879678]

# %%
ax5 = sns.stripplot(x, y);
ax5.set(xlabel = 'Tahun', ylabel = 'Jumlah Transaksi Cancel/Tahun')
plt.title('Grafik Jumlah Transaksi Cancel per Tahun')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Grafik Jumlah Transaksi Cancel per Tahun')

# %% [markdown]
# ### Interpretation

# %% [markdown]
# - Jumlah transaksi berhasil (finished) yang diperoleh dari penjualan ritel online di suatu perusahaan pada tahun 2009 dapat dikatakan cukup sedikit karena hanya terdapat sekitar 30761 customer saja yang berhasil melakukan transaksi dalam penjualan ritel online tersebut. Berbeda dengan jumlah transaksi berhasil (finished) pada tahun 2010 yang mengalami lonjakan atau kenaikan cukup signifikan menjadi 403094. Hal ini menunjukkan bahwa pada tahun 2010, pihak perusahaan ritel online melakukan pengembangan model pembayaran secara lebih efektif dan efisien, sehingga memberikan kemudahan bagi para customer dalam bertransaksi dan meningkatkan performa perusahaan. Dalam pengoperasiannya, jumlah transaksi berhasil (finished) pada tahun 2010 mengalami penurunan kembali menjadi 371765 customer, dengan penurunan grafik yang tidak terlalu signifikan.
#
# - Grafik jumlah transaksi yang dibatalkan (cancel) pada tahun 2009 di suatu perusahaan ritel online menunjukkan jumlah transaksi sebesar 1015. Pada tahun 2010, jumlah transaksi yang dibatalkan oleh para customer ritel online mengalami kenaikan yang cukup signifikan menjadi 9919, sedangkan jumlah transaksi yang dibatalkan pada tahun 2011 mengalami sedikit penurunan menjadi 8509. Semua titik pada grafik jumlah transaksi yang dibatalkan (cancel) tersebut menunjukkan posisi yang hampir sama dengan grafik jumlah transaksi yang berhasil (finished) dalam kurun waktu tiga tahun terakhir yaitu dari 2009, 2010, 2011.
#
# - Nilai cancellation rate yang diperoleh pada penjualan ritel online pada tahun 2009 yaitu sebesar 0.095%, pada tahun 2010 diperoleh sebesar 0.93%, dan pada tahun 2011 diperoleh sebesar 0.80%. Berdasarkan grafik cancellation rate yang diperoleh pada tahun 2009, 2010, dan 2011, menunjukkan bahwa persentase pelanggan atau customer yang melakukan pembatalan order dalam ritel online mengalami kenaikan yang cukup signifikan pada tahun 2009 ke tahun 2010 dan kemudian mengalami sedikit penurunan pada tahun 2010 ke tahun 2011.
#
# - Grafik jumlah transaksi yang dibatalkan (cancel) dan grafik cancellation rate pada setiap tahunnya menunjukkan posisi titik dengan kenaikan dan penurunan yang sama. Hal ini berarti bahwa persentase customer yang membatalkan order ritel online sebanding dengan jumlah transaksi yang dibatalkan oleh customer tersebut. Dengan demikian dapat disimpulkan bahwa grafik cancellation rate yang diperoleh menunjukkan hasil yang sesuai dengan perhitungan revenue maupun jumlah transaksi customer, baik transaksi yang berhasil (finished) hingga transaksi yang dibatalkan (cancel).
